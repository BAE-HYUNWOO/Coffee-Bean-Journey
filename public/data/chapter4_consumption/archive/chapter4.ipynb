# %%
import pandas as pd
print(pd.read_csv('disappearance.csv').columns.tolist())
print(pd.read_csv('domestic-consumption.csv').columns.tolist())
# Out:
# ['disappearance', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# ['domestic_consumption', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

# %%
import pandas as pd
from pathlib import Path

archive = Path('/Users/contramundum/Documents/pku/2026spring/数据可视化/小组5人/Coffee-Bean-Journey/public/data/chapter4_consumption/archive')
for f in archive.glob('*.csv'):
    cols = pd.read_csv(f, nrows=0).columns.tolist()
    print(f.name, cols)
# Out:
# retail-prices.csv ['retail_prices', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# gross-opening-stocks.csv ['gross_opening_stocks', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# exports-crop-year.csv ['exports_crop_year', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# ...
